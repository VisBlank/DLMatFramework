# %% [markdown]
# ## Tensorflow example
# Simple example of a linear regression using tensorflow.

# %% [markdown]
# ### Import libraries

# %%
# Import tensorflow, numpy, matplotlib libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Create dataset

# %%
# Create 100 phony x, y data points in NumPy, y = x * 0.1 + 0.3
x_data = np.random.rand(100).astype(np.float32)
y_data = x_data * 0.1 + 0.3

# Sample with matplotlib to plot some data (Like plot on matlab)
plt.plot(y_data)
plt.show()

# %% [markdown]
# ### Create graph structure

# %%
W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

# Minimize the mean squared errors.
loss = tf.reduce_mean(tf.square(y - y_data))

# %% [markdown]
# ### Configure model optimization

# %%
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %% [markdown]
# ### Initialize and build graph

# %%
# Before starting, initialize the variables.  We will 'run' this first.
init = tf.global_variables_initializer()

# Launch the graph.
sess = tf.Session()
sess.run(init)

# %% [markdown]
# ### Do the training

# %%
# Try to find values for W and b that compute y_data = W * x_data + b
# (We know that W should be 0.1 and b 0.3, but TensorFlow will
# figure that out for us.)

# Training
for step in range(201):
    sess.run(train)
    # Print each 20 iterations
    if step % 20 == 0:
        print(step, sess.run(W), sess.run(b))
# Out:
# 0 [ 0.60245156] [ 0.06261842]
# 20 [ 0.22218174] [ 0.23977955]
# 40 [ 0.12995374] [ 0.28523654]
# 60 [ 0.10734338] [ 0.29638064]
# 80 [ 0.10180029] [ 0.29911271]
# 100 [ 0.10044137] [ 0.29978248]
# 120 [ 0.1001082] [ 0.2999467]
# 140 [ 0.10002654] [ 0.29998693]
# 160 [ 0.10000651] [ 0.29999679]
# 180 [ 0.10000163] [ 0.29999921]
# 200 [ 0.1000004] [ 0.2999998]
