# %% [markdown]
# ## Trainning (Not using TFRecords)
#
# ### What you will see
# Basically how to train a network on tensorflow.
# 1. Model definition
# 2. Loss definition
# 3. Session build

# %%
import tensorflow as tf
import sys
sys.path.append('../')
import model
import os
import subprocess
import glob
from driving_data import HandleData


# Regularization value
L2NormConst = 0.001
start_lr = 0.001
batch_size=100
epochs = 600
input_train_hdf5 = '../Track1_LMDB_Unbalanced'
input_val_hdf5 = '../DatasetLMDB_Wheel_Test'
logs_path = '../logs'
save_dir = '../save'
iter_disp = 10
gpu_fraction = 0.3

os.environ["CUDA_VISIBLE_DEVICES"] = str(0)

# %% [markdown]
# ### Define the model

# %%
# Open Model
driving_model = model.DrivingModel()
    
# Get placeholders from model
model_in = driving_model.input
model_out = driving_model.output
labels_in = driving_model.label_in
model_drop = driving_model.dropout_control

# %% [markdown]
# ### Create the Session
# Basically ask tensorflow to build the graph

# %%
# Avoid allocating the whole memory
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=gpu_fraction)
sess = tf.InteractiveSession(config=tf.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# ### Define Loss function

# %%
train_vars = tf.trainable_variables()
with tf.name_scope("MSE_Loss_L2Reg"):
    loss = tf.reduce_mean(tf.square(tf.subtract(labels_in, model_out))) + tf.add_n(
        [tf.nn.l2_loss(v) for v in train_vars]) * L2NormConst

# Add model accuracy
with tf.name_scope("Loss_Validation"):
    loss_val = tf.reduce_mean(tf.square(tf.subtract(labels_in, model_out)))

# %% [markdown]
# ### Define the solver
# We want to use the Adam solver to minimize or loss function.

# %%
# Solver configuration
# Get ops to update moving_mean and moving_variance from batch_norm
# Reference: https://www.tensorflow.org/api_docs/python/tf/contrib/layers/batch_norm
update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
with tf.name_scope("Solver"):
    global_step = tf.Variable(0, trainable=False)
    starter_learning_rate = start_lr
    # decay every 10000 steps with a base of 0.96
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step,
                                               1000, 0.9, staircase=True)

    # Basically update the batch_norm moving averages before the training step
    # http://ruishu.io/2016/12/27/batchnorm/
    with tf.control_dependencies(update_ops):
        train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss, global_step=global_step)

# %% [markdown]
# ### Initialize the values (Random values of weights)

# %%
# Initialize all random variables (Weights/Bias)
sess.run(tf.global_variables_initializer())

# %% [markdown]
# ### Define saver object to save checkpoints

# %%
# Define saver object to save all the variables of the drivingModel graph
saver = tf.train.Saver()

# %% [markdown]
# ### Add some variables to be observed on Tensorboard

# %%
# Create histogram for labels
tf.summary.histogram("steer_angle", labels_in)
# Add input image/steering angle on summary
tf.summary.image("input_image", model_in, 10)

# Monitor loss, learning_rate, global_step, etc...
tf.summary.scalar("loss_train", loss)
tf.summary.scalar("learning_rate", learning_rate)
tf.summary.scalar("global_step", global_step)
# merge all summaries into a single op
merged_summary_op = tf.summary.merge_all()

# Configure where to save the logs for tensorboard
summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())

# %% [markdown]
# ### Load the dataset

# %%
data = HandleData(path=input_train_hdf5, path_val=input_val_hdf5)
num_images_epoch = int(data.get_num_images() / batch_size)
print('Num samples',data.get_num_images(), 'Iterations per epoch:', num_images_epoch, 'batch size:', batch_size)
# Out:
# Loading training data
# LMDB file
# Load validation dataset
# Number training images: 1040
# Number validation images: 1480
# Num samples 1040 Iterations per epoch: 10 batch size: 100

# %% [markdown]
# ### Do training

# %%
# For each epoch
for epoch in range(epochs):
    for i in range(int(data.get_num_images() / batch_size)):
        # Get training batch
        xs_train, ys_train = data.LoadTrainBatch(batch_size, should_augment=True)

        # Send training batch to tensorflow graph (Dropout enabled)
        train_step.run(feed_dict={model_in: xs_train, labels_in: ys_train, model_drop: 0.8})

        # Display some information each x iterations
        if i % iter_disp == 0:
            # Get validation batch
            xs, ys = data.LoadValBatch(batch_size)
            # Send validation batch to tensorflow graph (Dropout disabled)
            loss_value = loss_val.eval(feed_dict={model_in: xs, labels_in: ys, model_drop: 1.0})
            print("Epoch: %d, Step: %d, Loss(Val): %g" % (epoch, epoch * batch_size + i, loss_value))

        # write logs at every iteration
        summary = merged_summary_op.eval(feed_dict={model_in: xs_train, labels_in: ys_train, model_drop: 1.0})
        summary_writer.add_summary(summary, epoch * batch_size + i)

    # Save checkpoint after each epoch
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)
    checkpoint_path = os.path.join(save_dir, "model")
    filename = saver.save(sess, checkpoint_path, global_step=epoch)
    print("Model saved in file: %s" % filename)

    # Shuffle data at each epoch end
    print("Shuffle data")
    data.shuffleData()
# Out:
# Epoch: 0, Step: 0, Loss(Val): 0.158225
# Model saved in file: ../save/model-0
# Shuffle data
# Epoch: 1, Step: 100, Loss(Val): 0.0594684
# Model saved in file: ../save/model-1
# Shuffle data
# Epoch: 2, Step: 200, Loss(Val): 0.0848938
# Model saved in file: ../save/model-2
# Shuffle data
# Epoch: 3, Step: 300, Loss(Val): 0.0765659
# Model saved in file: ../save/model-3
# Shuffle data
# Epoch: 4, Step: 400, Loss(Val): 0.0576228
# Model saved in file: ../save/model-4
# Shuffle data
# Epoch: 5, Step: 500, Loss(Val): 0.0784099
# Model saved in file: ../save/model-5
# Shuffle data
# Epoch: 6, Step: 600, Loss(Val): 0.0810263
# Model saved in file: ../save/model-6
# Shuffle data
# Epoch: 7, Step: 700, Loss(Val): 0.0541961
# Model saved in file: ../save/model-7
# Shuffle data
# Epoch: 8, Step: 800, Loss(Val): 0.0680012
# Model saved in file: ../save/model-8
# Shuffle data
# Epoch: 9, Step: 900, Loss(Val): 0.0700402
# Model saved in file: ../save/model-9
# Shuffle data
# Epoch: 10, Step: 1000, Loss(Val): 0.0632122
# Model saved in file: ../save/model-10
# Shuffle data
# Epoch: 11, Step: 1100, Loss(Val): 0.0780561
# Model saved in file: ../save/model-11
# Shuffle data
# Epoch: 12, Step: 1200, Loss(Val): 0.0731978
# Model saved in file: ../save/model-12
# Shuffle data
# Epoch: 13, Step: 1300, Loss(Val): 0.0600099
# Model saved in file: ../save/model-13
# Shuffle data
# Epoch: 14, Step: 1400, Loss(Val): 0.0744323
# Model saved in file: ../save/model-14
# Shuffle data
# Epoch: 15, Step: 1500, Loss(Val): 0.0737031
# Model saved in file: ../save/model-15
# Shuffle data
# Epoch: 16, Step: 1600, Loss(Val): 0.063599
# Model saved in file: ../save/model-16
# Shuffle data
# Epoch: 17, Step: 1700, Loss(Val): 0.0612676
# Model saved in file: ../save/model-17
# Shuffle data
# Epoch: 18, Step: 1800, Loss(Val): 0.0753044
# Model saved in file: ../save/model-18
# Shuffle data
# Epoch: 19, Step: 1900, Loss(Val): 0.0687978
# Model saved in file: ../save/model-19
# Shuffle data
# Epoch: 20, Step: 2000, Loss(Val): 0.0600778
# Model saved in file: ../save/model-20
# Shuffle data
# Epoch: 21, Step: 2100, Loss(Val): 0.0722993
# Model saved in file: ../save/model-21
# Shuffle data
# Epoch: 22, Step: 2200, Loss(Val): 0.0800195
# Model saved in file: ../save/model-22
# Shuffle data
# Epoch: 23, Step: 2300, Loss(Val): 0.0611617
# Model saved in file: ../save/model-23
# Shuffle data
# Epoch: 24, Step: 2400, Loss(Val): 0.0688216
# Model saved in file: ../save/model-24
# Shuffle data
# Epoch: 25, Step: 2500, Loss(Val): 0.0845517
# Model saved in file: ../save/model-25
# Shuffle data
# Epoch: 26, Step: 2600, Loss(Val): 0.0491378
# Model saved in file: ../save/model-26
# Shuffle data
# Epoch: 27, Step: 2700, Loss(Val): 0.0764127
# Model saved in file: ../save/model-27
# Shuffle data
# Epoch: 28, Step: 2800, Loss(Val): 0.0945556
# Model saved in file: ../save/model-28
# Shuffle data
# Epoch: 29, Step: 2900, Loss(Val): 0.0421752
# Model saved in file: ../save/model-29
# Shuffle data
# Epoch: 30, Step: 3000, Loss(Val): 0.0642442
# Model saved in file: ../save/model-30
# Shuffle data
# Epoch: 31, Step: 3100, Loss(Val): 0.102577
# Model saved in file: ../save/model-31
# Shuffle data
# Epoch: 32, Step: 3200, Loss(Val): 0.0434711
# Model saved in file: ../save/model-32
# Shuffle data
# Epoch: 33, Step: 3300, Loss(Val): 0.0578992
# Model saved in file: ../save/model-33
# Shuffle data
# Epoch: 34, Step: 3400, Loss(Val): 0.0733675
# Model saved in file: ../save/model-34
# Shuffle data
# Epoch: 35, Step: 3500, Loss(Val): 0.0738144
# Model saved in file: ../save/model-35
# Shuffle data
# Epoch: 36, Step: 3600, Loss(Val): 0.0715467
# Model saved in file: ../save/model-36
# Shuffle data
# Epoch: 37, Step: 3700, Loss(Val): 0.0739845
# Model saved in file: ../save/model-37
# Shuffle data
# Epoch: 38, Step: 3800, Loss(Val): 0.0589217
# Model saved in file: ../save/model-38
# Shuffle data
# Epoch: 39, Step: 3900, Loss(Val): 0.081659
# Model saved in file: ../save/model-39
# Shuffle data
# Epoch: 40, Step: 4000, Loss(Val): 0.0657732
# Model saved in file: ../save/model-40
# Shuffle data
# Epoch: 41, Step: 4100, Loss(Val): 0.0560516
# Model saved in file: ../save/model-41
# Shuffle data
# Epoch: 42, Step: 4200, Loss(Val): 0.0771485
# Model saved in file: ../save/model-42
# Shuffle data
# Epoch: 43, Step: 4300, Loss(Val): 0.080956
# Model saved in file: ../save/model-43
# Shuffle data
# Epoch: 44, Step: 4400, Loss(Val): 0.0583799
# Model saved in file: ../save/model-44
# Shuffle data
# Epoch: 45, Step: 4500, Loss(Val): 0.0673764
# Model saved in file: ../save/model-45
# Shuffle data
# Epoch: 46, Step: 4600, Loss(Val): 0.0682636
# Model saved in file: ../save/model-46
# Shuffle data
# Epoch: 47, Step: 4700, Loss(Val): 0.0633111
# Model saved in file: ../save/model-47
# Shuffle data
# Epoch: 48, Step: 4800, Loss(Val): 0.0778526
# Model saved in file: ../save/model-48
# Shuffle data
# Epoch: 49, Step: 4900, Loss(Val): 0.0757075
# Model saved in file: ../save/model-49
# Shuffle data
# Epoch: 50, Step: 5000, Loss(Val): 0.0574883
# Model saved in file: ../save/model-50
# Shuffle data
# Epoch: 51, Step: 5100, Loss(Val): 0.0746324
# Model saved in file: ../save/model-51
# Shuffle data
# Epoch: 52, Step: 5200, Loss(Val): 0.0784691
# Model saved in file: ../save/model-52
# Shuffle data
# Epoch: 53, Step: 5300, Loss(Val): 0.0605716
# Model saved in file: ../save/model-53
# Shuffle data
# Epoch: 54, Step: 5400, Loss(Val): 0.0598845
# Model saved in file: ../save/model-54
# Shuffle data
# Epoch: 55, Step: 5500, Loss(Val): 0.076299
# Model saved in file: ../save/model-55
# Shuffle data
# Epoch: 56, Step: 5600, Loss(Val): 0.0720183
# Model saved in file: ../save/model-56
# Shuffle data
# Epoch: 57, Step: 5700, Loss(Val): 0.0598155
# Model saved in file: ../save/model-57
# Shuffle data
# Epoch: 58, Step: 5800, Loss(Val): 0.0778859
# Model saved in file: ../save/model-58
# Shuffle data
# Epoch: 59, Step: 5900, Loss(Val): 0.0847129
# Model saved in file: ../save/model-59
# Shuffle data
# Epoch: 60, Step: 6000, Loss(Val): 0.0616076
# Model saved in file: ../save/model-60
# Shuffle data
# Epoch: 61, Step: 6100, Loss(Val): 0.0816581
# Model saved in file: ../save/model-61
# Shuffle data
# Epoch: 62, Step: 6200, Loss(Val): 0.0933482
# Model saved in file: ../save/model-62
# Shuffle data
# Epoch: 63, Step: 6300, Loss(Val): 0.0515662
# Model saved in file: ../save/model-63
# Shuffle data
# Epoch: 64, Step: 6400, Loss(Val): 0.0811715
# Model saved in file: ../save/model-64
# Shuffle data
# Epoch: 65, Step: 6500, Loss(Val): 0.10034
# Model saved in file: ../save/model-65
# Shuffle data
# Epoch: 66, Step: 6600, Loss(Val): 0.0447345
# Model saved in file: ../save/model-66
# Shuffle data
# Epoch: 67, Step: 6700, Loss(Val): 0.0692252
# Model saved in file: ../save/model-67
# Shuffle data
# Epoch: 68, Step: 6800, Loss(Val): 0.105534
# Model saved in file: ../save/model-68
# Shuffle data
# Epoch: 69, Step: 6900, Loss(Val): 0.0487754
# Model saved in file: ../save/model-69
# Shuffle data
# Epoch: 70, Step: 7000, Loss(Val): 0.060221
# Model saved in file: ../save/model-70
# Shuffle data
# Epoch: 71, Step: 7100, Loss(Val): 0.0777447
# Model saved in file: ../save/model-71
# Shuffle data
# Epoch: 72, Step: 7200, Loss(Val): 0.0742105
# Model saved in file: ../save/model-72
# Shuffle data
# Epoch: 73, Step: 7300, Loss(Val): 0.0745267
# Model saved in file: ../save/model-73
# Shuffle data
# Epoch: 74, Step: 7400, Loss(Val): 0.0787814
# Model saved in file: ../save/model-74
# Shuffle data
# Epoch: 75, Step: 7500, Loss(Val): 0.061775
# Model saved in file: ../save/model-75
# Shuffle data
# Epoch: 76, Step: 7600, Loss(Val): 0.0846327
# Model saved in file: ../save/model-76
# Shuffle data
# Epoch: 77, Step: 7700, Loss(Val): 0.0724776
# Model saved in file: ../save/model-77
# Shuffle data
# Epoch: 78, Step: 7800, Loss(Val): 0.0578829
# Model saved in file: ../save/model-78
# Shuffle data
# Epoch: 79, Step: 7900, Loss(Val): 0.087305
# Model saved in file: ../save/model-79
# Shuffle data
# Epoch: 80, Step: 8000, Loss(Val): 0.0919723
# Model saved in file: ../save/model-80
# Shuffle data
# Epoch: 81, Step: 8100, Loss(Val): 0.0601351
# Model saved in file: ../save/model-81
# Shuffle data
# Epoch: 82, Step: 8200, Loss(Val): 0.0728173
# Model saved in file: ../save/model-82
# Shuffle data
# Epoch: 83, Step: 8300, Loss(Val): 0.081172
# Model saved in file: ../save/model-83
# Shuffle data
# Epoch: 84, Step: 8400, Loss(Val): 0.0648947
# Model saved in file: ../save/model-84
# Shuffle data
# Epoch: 85, Step: 8500, Loss(Val): 0.0809905
# Model saved in file: ../save/model-85
# Shuffle data
# Epoch: 86, Step: 8600, Loss(Val): 0.0812759
# Model saved in file: ../save/model-86
# Shuffle data
# Epoch: 87, Step: 8700, Loss(Val): 0.0676486
# Model saved in file: ../save/model-87
# Shuffle data
# Epoch: 88, Step: 8800, Loss(Val): 0.0768791
# Model saved in file: ../save/model-88
# Shuffle data
# Epoch: 89, Step: 8900, Loss(Val): 0.0809193
# Model saved in file: ../save/model-89
# Shuffle data
# Epoch: 90, Step: 9000, Loss(Val): 0.0623412
# Model saved in file: ../save/model-90
# Shuffle data
# Epoch: 91, Step: 9100, Loss(Val): 0.0634151
# Model saved in file: ../save/model-91
# Shuffle data
# Epoch: 92, Step: 9200, Loss(Val): 0.0725745
# Model saved in file: ../save/model-92
# Shuffle data
# Epoch: 93, Step: 9300, Loss(Val): 0.0645027
# Model saved in file: ../save/model-93
# Shuffle data
# Epoch: 94, Step: 9400, Loss(Val): 0.0563689
# Model saved in file: ../save/model-94
# Shuffle data
# Epoch: 95, Step: 9500, Loss(Val): 0.069392
# Model saved in file: ../save/model-95
# Shuffle data
# Epoch: 96, Step: 9600, Loss(Val): 0.0873206
# Model saved in file: ../save/model-96
# Shuffle data
# Epoch: 97, Step: 9700, Loss(Val): 0.0629034
# Model saved in file: ../save/model-97
# Shuffle data
# Epoch: 98, Step: 9800, Loss(Val): 0.0704072
# Model saved in file: ../save/model-98
# Shuffle data
# Epoch: 99, Step: 9900, Loss(Val): 0.0915243
# Model saved in file: ../save/model-99
# Shuffle data
# Epoch: 100, Step: 10000, Loss(Val): 0.048171
# Model saved in file: ../save/model-100
# Shuffle data
# Epoch: 101, Step: 10100, Loss(Val): 0.0736402
# Model saved in file: ../save/model-101
# Shuffle data
# Epoch: 102, Step: 10200, Loss(Val): 0.104952
# Model saved in file: ../save/model-102
# Shuffle data
# Epoch: 103, Step: 10300, Loss(Val): 0.0415669
# Model saved in file: ../save/model-103
# Shuffle data
# Epoch: 104, Step: 10400, Loss(Val): 0.0654955
# Model saved in file: ../save/model-104
# Shuffle data
# Epoch: 105, Step: 10500, Loss(Val): 0.0978062
# Model saved in file: ../save/model-105
# Shuffle data
# Epoch: 106, Step: 10600, Loss(Val): 0.0448486
# Model saved in file: ../save/model-106
# Shuffle data
# Epoch: 107, Step: 10700, Loss(Val): 0.0573226
# Model saved in file: ../save/model-107
# Shuffle data
# Epoch: 108, Step: 10800, Loss(Val): 0.0836626
# Model saved in file: ../save/model-108
# Shuffle data
# Epoch: 109, Step: 10900, Loss(Val): 0.0805837
# Model saved in file: ../save/model-109
# Shuffle data
# Epoch: 110, Step: 11000, Loss(Val): 0.0806252
# Model saved in file: ../save/model-110
# Shuffle data
# Epoch: 111, Step: 11100, Loss(Val): 0.0819035
# Model saved in file: ../save/model-111
# Shuffle data
# Epoch: 112, Step: 11200, Loss(Val): 0.0703684
# Model saved in file: ../save/model-112
# Shuffle data
# Epoch: 113, Step: 11300, Loss(Val): 0.0914693
# Model saved in file: ../save/model-113
# Shuffle data
# Epoch: 114, Step: 11400, Loss(Val): 0.0755092
# Model saved in file: ../save/model-114
# Shuffle data
# Epoch: 115, Step: 11500, Loss(Val): 0.0603147
# Model saved in file: ../save/model-115
# Shuffle data
# Epoch: 116, Step: 11600, Loss(Val): 0.0871582
# Model saved in file: ../save/model-116
# Shuffle data
# Epoch: 117, Step: 11700, Loss(Val): 0.0825904
# Model saved in file: ../save/model-117
# Shuffle data
# Epoch: 118, Step: 11800, Loss(Val): 0.0660981
# Model saved in file: ../save/model-118
# Shuffle data
# Epoch: 119, Step: 11900, Loss(Val): 0.0724783
# Model saved in file: ../save/model-119
# Shuffle data
# Epoch: 120, Step: 12000, Loss(Val): 0.0842065
# Model saved in file: ../save/model-120
# Shuffle data
# Epoch: 121, Step: 12100, Loss(Val): 0.0778416
# Model saved in file: ../save/model-121
# Shuffle data
# Epoch: 122, Step: 12200, Loss(Val): 0.0761717
# Model saved in file: ../save/model-122
# Shuffle data
# Epoch: 123, Step: 12300, Loss(Val): 0.0830246
# Model saved in file: ../save/model-123
# Shuffle data
# Epoch: 124, Step: 12400, Loss(Val): 0.0639487
# Model saved in file: ../save/model-124
# Shuffle data
# Epoch: 125, Step: 12500, Loss(Val): 0.0718097
# Model saved in file: ../save/model-125
# Shuffle data
# Epoch: 126, Step: 12600, Loss(Val): 0.0843457
# Model saved in file: ../save/model-126
# Shuffle data
# Epoch: 127, Step: 12700, Loss(Val): 0.067121
# Model saved in file: ../save/model-127
# Shuffle data
# Epoch: 128, Step: 12800, Loss(Val): 0.0633879
# Model saved in file: ../save/model-128
# Shuffle data
# Epoch: 129, Step: 12900, Loss(Val): 0.082712
# Model saved in file: ../save/model-129
# Shuffle data
# Epoch: 130, Step: 13000, Loss(Val): 0.0704951
# Model saved in file: ../save/model-130
# Shuffle data
# Epoch: 131, Step: 13100, Loss(Val): 0.0598849
# Model saved in file: ../save/model-131
# Shuffle data
# Epoch: 132, Step: 13200, Loss(Val): 0.0776196
# Model saved in file: ../save/model-132
# Shuffle data
# Epoch: 133, Step: 13300, Loss(Val): 0.0880666
# Model saved in file: ../save/model-133
# Shuffle data
# Epoch: 134, Step: 13400, Loss(Val): 0.0693061
# Model saved in file: ../save/model-134
# Shuffle data
# Epoch: 135, Step: 13500, Loss(Val): 0.0779114
# Model saved in file: ../save/model-135
# Shuffle data
# Epoch: 136, Step: 13600, Loss(Val): 0.0986042
# Model saved in file: ../save/model-136
# Shuffle data
# Epoch: 137, Step: 13700, Loss(Val): 0.050589
# Model saved in file: ../save/model-137
# Shuffle data
# Epoch: 138, Step: 13800, Loss(Val): 0.0795762
# Model saved in file: ../save/model-138
# Shuffle data
# Epoch: 139, Step: 13900, Loss(Val): 0.113101
# Model saved in file: ../save/model-139
# Shuffle data
# Epoch: 140, Step: 14000, Loss(Val): 0.0418551
# Model saved in file: ../save/model-140
# Shuffle data
# Epoch: 141, Step: 14100, Loss(Val): 0.0622756
# Model saved in file: ../save/model-141
# Shuffle data
# Epoch: 142, Step: 14200, Loss(Val): 0.108359
# Model saved in file: ../save/model-142
# Shuffle data
# Epoch: 143, Step: 14300, Loss(Val): 0.047785
# Model saved in file: ../save/model-143
# Shuffle data
# Epoch: 144, Step: 14400, Loss(Val): 0.0685695
# Model saved in file: ../save/model-144
# Shuffle data
# Epoch: 145, Step: 14500, Loss(Val): 0.0751795
# Model saved in file: ../save/model-145
# Shuffle data
# Epoch: 146, Step: 14600, Loss(Val): 0.0769266
# Model saved in file: ../save/model-146
# Shuffle data
# Epoch: 147, Step: 14700, Loss(Val): 0.0844654
# Model saved in file: ../save/model-147
# Shuffle data
# Epoch: 148, Step: 14800, Loss(Val): 0.0804685
# Model saved in file: ../save/model-148
# Shuffle data
# Epoch: 149, Step: 14900, Loss(Val): 0.0644147
# Model saved in file: ../save/model-149
# Shuffle data
# Epoch: 150, Step: 15000, Loss(Val): 0.0966123
# Model saved in file: ../save/model-150
# Shuffle data
# Epoch: 151, Step: 15100, Loss(Val): 0.0837486
# Model saved in file: ../save/model-151
# Shuffle data
# Epoch: 152, Step: 15200, Loss(Val): 0.0573069
# Model saved in file: ../save/model-152
# Shuffle data
# Epoch: 153, Step: 15300, Loss(Val): 0.0842407
# Model saved in file: ../save/model-153
# Shuffle data
# Epoch: 154, Step: 15400, Loss(Val): 0.083709
# Model saved in file: ../save/model-154
# Shuffle data
# Epoch: 155, Step: 15500, Loss(Val): 0.0620338
# Model saved in file: ../save/model-155
# Shuffle data
# Epoch: 156, Step: 15600, Loss(Val): 0.0849826
# Model saved in file: ../save/model-156
# Shuffle data
# Epoch: 157, Step: 15700, Loss(Val): 0.0821758
# Model saved in file: ../save/model-157
# Shuffle data
# Epoch: 158, Step: 15800, Loss(Val): 0.0763797
# Model saved in file: ../save/model-158
# Shuffle data
# Epoch: 159, Step: 15900, Loss(Val): 0.0759082
# Model saved in file: ../save/model-159
# Shuffle data
# Epoch: 160, Step: 16000, Loss(Val): 0.0810256
# Model saved in file: ../save/model-160
# Shuffle data
# Epoch: 161, Step: 16100, Loss(Val): 0.0625053
# Model saved in file: ../save/model-161
# Shuffle data
# Epoch: 162, Step: 16200, Loss(Val): 0.064503
# Model saved in file: ../save/model-162
# Shuffle data
# Epoch: 163, Step: 16300, Loss(Val): 0.0765766
# Model saved in file: ../save/model-163
# Shuffle data
# Epoch: 164, Step: 16400, Loss(Val): 0.0571935
# Model saved in file: ../save/model-164
# Shuffle data
# Epoch: 165, Step: 16500, Loss(Val): 0.0562412
# Model saved in file: ../save/model-165
# Shuffle data
# Epoch: 166, Step: 16600, Loss(Val): 0.0804492
# Model saved in file: ../save/model-166
# Shuffle data
# Epoch: 167, Step: 16700, Loss(Val): 0.0746709
# Model saved in file: ../save/model-167
# Shuffle data
# Epoch: 168, Step: 16800, Loss(Val): 0.0566817
# Model saved in file: ../save/model-168
# Shuffle data
# Epoch: 169, Step: 16900, Loss(Val): 0.0861233
# Model saved in file: ../save/model-169
# Shuffle data
# Epoch: 170, Step: 17000, Loss(Val): 0.0880997
# Model saved in file: ../save/model-170
# Shuffle data
# Epoch: 171, Step: 17100, Loss(Val): 0.0664203
# Model saved in file: ../save/model-171
# Shuffle data
# Epoch: 172, Step: 17200, Loss(Val): 0.0762146
# Model saved in file: ../save/model-172
# Shuffle data
# Epoch: 173, Step: 17300, Loss(Val): 0.0982603
# Model saved in file: ../save/model-173
# Shuffle data
# Epoch: 174, Step: 17400, Loss(Val): 0.0497929
# Model saved in file: ../save/model-174
# Shuffle data
# Epoch: 175, Step: 17500, Loss(Val): 0.0756511
# Model saved in file: ../save/model-175
# Shuffle data
# Epoch: 176, Step: 17600, Loss(Val): 0.110144
# Model saved in file: ../save/model-176
# Shuffle data
# Epoch: 177, Step: 17700, Loss(Val): 0.0491103
# Model saved in file: ../save/model-177
# Shuffle data
# Epoch: 178, Step: 17800, Loss(Val): 0.0699053
# Model saved in file: ../save/model-178
# Shuffle data
# Epoch: 179, Step: 17900, Loss(Val): 0.110022
# Model saved in file: ../save/model-179
# Shuffle data
# Epoch: 180, Step: 18000, Loss(Val): 0.0512579
# Model saved in file: ../save/model-180
# Shuffle data
# Epoch: 181, Step: 18100, Loss(Val): 0.0698172
# Model saved in file: ../save/model-181
# Shuffle data
# Epoch: 182, Step: 18200, Loss(Val): 0.0733604
# Model saved in file: ../save/model-182
# Shuffle data
# Epoch: 183, Step: 18300, Loss(Val): 0.0791175
# Model saved in file: ../save/model-183
# Shuffle data
# Epoch: 184, Step: 18400, Loss(Val): 0.081559
# Model saved in file: ../save/model-184
# Shuffle data
# Epoch: 185, Step: 18500, Loss(Val): 0.0900131
# Model saved in file: ../save/model-185
# Shuffle data
# Epoch: 186, Step: 18600, Loss(Val): 0.0746471
# Model saved in file: ../save/model-186
# Shuffle data
# Epoch: 187, Step: 18700, Loss(Val): 0.0963861
# Model saved in file: ../save/model-187
# Shuffle data
# Epoch: 188, Step: 18800, Loss(Val): 0.085626
# Model saved in file: ../save/model-188
# Shuffle data
# Epoch: 189, Step: 18900, Loss(Val): 0.0637545
# Model saved in file: ../save/model-189
# Shuffle data
# Epoch: 190, Step: 19000, Loss(Val): 0.10346
# Model saved in file: ../save/model-190
# Shuffle data
# Epoch: 191, Step: 19100, Loss(Val): 0.0921438
# Model saved in file: ../save/model-191
# Shuffle data
# Epoch: 192, Step: 19200, Loss(Val): 0.0652698
# Model saved in file: ../save/model-192
# Shuffle data
# Epoch: 193, Step: 19300, Loss(Val): 0.0826016
# Model saved in file: ../save/model-193
# Shuffle data
# Epoch: 194, Step: 19400, Loss(Val): 0.0781757
# Model saved in file: ../save/model-194
# Shuffle data
# Epoch: 195, Step: 19500, Loss(Val): 0.07132
# Model saved in file: ../save/model-195
# Shuffle data
# Epoch: 196, Step: 19600, Loss(Val): 0.0863379
# Model saved in file: ../save/model-196
# Shuffle data
# Epoch: 197, Step: 19700, Loss(Val): 0.0846078
# Model saved in file: ../save/model-197
# Shuffle data
# Epoch: 198, Step: 19800, Loss(Val): 0.069625
# Model saved in file: ../save/model-198
# Shuffle data
# Epoch: 199, Step: 19900, Loss(Val): 0.0807221
# Model saved in file: ../save/model-199
# Shuffle data
# Epoch: 200, Step: 20000, Loss(Val): 0.0800144
# Model saved in file: ../save/model-200
# Shuffle data
# Epoch: 201, Step: 20100, Loss(Val): 0.0694683
# Model saved in file: ../save/model-201
# Shuffle data
# Epoch: 202, Step: 20200, Loss(Val): 0.0694692
# Model saved in file: ../save/model-202
# Shuffle data
# Epoch: 203, Step: 20300, Loss(Val): 0.0884886
# Model saved in file: ../save/model-203
# Shuffle data
# Epoch: 204, Step: 20400, Loss(Val): 0.064391
# Model saved in file: ../save/model-204
# Shuffle data
# Epoch: 205, Step: 20500, Loss(Val): 0.0622968
# Model saved in file: ../save/model-205
# Shuffle data
# Epoch: 206, Step: 20600, Loss(Val): 0.0805594
# Model saved in file: ../save/model-206
# Shuffle data
# Epoch: 207, Step: 20700, Loss(Val): 0.0942733
# Model saved in file: ../save/model-207
# Shuffle data
# Epoch: 208, Step: 20800, Loss(Val): 0.0635002
# Model saved in file: ../save/model-208
# Shuffle data
# Epoch: 209, Step: 20900, Loss(Val): 0.0743047
# Model saved in file: ../save/model-209
# Shuffle data
# Epoch: 210, Step: 21000, Loss(Val): 0.0963913
# Model saved in file: ../save/model-210
# Shuffle data
# Epoch: 211, Step: 21100, Loss(Val): 0.0566237
# Model saved in file: ../save/model-211
# Shuffle data
# Epoch: 212, Step: 21200, Loss(Val): 0.0855055
# Model saved in file: ../save/model-212
# Shuffle data
# Epoch: 213, Step: 21300, Loss(Val): 0.101311
# Model saved in file: ../save/model-213
# Shuffle data
# Epoch: 214, Step: 21400, Loss(Val): 0.0448668
# Model saved in file: ../save/model-214
# Shuffle data
# Epoch: 215, Step: 21500, Loss(Val): 0.0772097
# Model saved in file: ../save/model-215
# Shuffle data
# Epoch: 216, Step: 21600, Loss(Val): 0.103035
# Model saved in file: ../save/model-216
# Shuffle data
# Epoch: 217, Step: 21700, Loss(Val): 0.0473673
# Model saved in file: ../save/model-217
# Shuffle data
# Epoch: 218, Step: 21800, Loss(Val): 0.0628185
# Model saved in file: ../save/model-218
# Shuffle data
# Epoch: 219, Step: 21900, Loss(Val): 0.0739318
# Model saved in file: ../save/model-219
# Shuffle data
# Epoch: 220, Step: 22000, Loss(Val): 0.0810716
# Model saved in file: ../save/model-220
# Shuffle data
# Epoch: 221, Step: 22100, Loss(Val): 0.0778691
# Model saved in file: ../save/model-221
# Shuffle data
# Epoch: 222, Step: 22200, Loss(Val): 0.0914002
# Model saved in file: ../save/model-222
# Shuffle data
# Epoch: 223, Step: 22300, Loss(Val): 0.0666397
# Model saved in file: ../save/model-223
# Shuffle data
# Epoch: 224, Step: 22400, Loss(Val): 0.0922965
# Model saved in file: ../save/model-224
# Shuffle data
# Epoch: 225, Step: 22500, Loss(Val): 0.0827792
# Model saved in file: ../save/model-225
# Shuffle data
# Epoch: 226, Step: 22600, Loss(Val): 0.0643344
# Model saved in file: ../save/model-226
# Shuffle data
# Epoch: 227, Step: 22700, Loss(Val): 0.100401
# Model saved in file: ../save/model-227
# Shuffle data
# Epoch: 228, Step: 22800, Loss(Val): 0.0934155
# Model saved in file: ../save/model-228
# Shuffle data
# Epoch: 229, Step: 22900, Loss(Val): 0.0632705
# Model saved in file: ../save/model-229
# Shuffle data
# Epoch: 230, Step: 23000, Loss(Val): 0.0785995
# Model saved in file: ../save/model-230
# Shuffle data
# Epoch: 231, Step: 23100, Loss(Val): 0.0718075
# Model saved in file: ../save/model-231
# Shuffle data
# Epoch: 232, Step: 23200, Loss(Val): 0.0735194
# Model saved in file: ../save/model-232
# Shuffle data
# Epoch: 233, Step: 23300, Loss(Val): 0.087503
# Model saved in file: ../save/model-233
# Shuffle data
# Epoch: 234, Step: 23400, Loss(Val): 0.0861624
# Model saved in file: ../save/model-234
# Shuffle data
# Epoch: 235, Step: 23500, Loss(Val): 0.0677047
# Model saved in file: ../save/model-235
# Shuffle data
# Epoch: 236, Step: 23600, Loss(Val): 0.081584
# Model saved in file: ../save/model-236
# Shuffle data
# Epoch: 237, Step: 23700, Loss(Val): 0.0811094
# Model saved in file: ../save/model-237
# Shuffle data
# Epoch: 238, Step: 23800, Loss(Val): 0.0599643
# Model saved in file: ../save/model-238
# Shuffle data
# Epoch: 239, Step: 23900, Loss(Val): 0.0623058
# Model saved in file: ../save/model-239
# Shuffle data
# Epoch: 240, Step: 24000, Loss(Val): 0.0887314
# Model saved in file: ../save/model-240
# Shuffle data
# Epoch: 241, Step: 24100, Loss(Val): 0.0659123
# Model saved in file: ../save/model-241
# Shuffle data
# Epoch: 242, Step: 24200, Loss(Val): 0.0610233
# Model saved in file: ../save/model-242
# Shuffle data
# Epoch: 243, Step: 24300, Loss(Val): 0.0777754
# Model saved in file: ../save/model-243
# Shuffle data
# Epoch: 244, Step: 24400, Loss(Val): 0.0869499
# Model saved in file: ../save/model-244
# Shuffle data
# Epoch: 245, Step: 24500, Loss(Val): 0.0665248
# Model saved in file: ../save/model-245
# Shuffle data
# Epoch: 246, Step: 24600, Loss(Val): 0.0675204
# Model saved in file: ../save/model-246
# Shuffle data
# Epoch: 247, Step: 24700, Loss(Val): 0.0822898
# Model saved in file: ../save/model-247
# Shuffle data
# Epoch: 248, Step: 24800, Loss(Val): 0.0485636
# Model saved in file: ../save/model-248
# Shuffle data
# Epoch: 249, Step: 24900, Loss(Val): 0.0799613
# Model saved in file: ../save/model-249
# Shuffle data
# Epoch: 250, Step: 25000, Loss(Val): 0.108898
# Model saved in file: ../save/model-250
# Shuffle data
# Epoch: 251, Step: 25100, Loss(Val): 0.0385501
# Model saved in file: ../save/model-251
# Shuffle data
# Epoch: 252, Step: 25200, Loss(Val): 0.0651171
# Model saved in file: ../save/model-252
# Shuffle data
# Epoch: 253, Step: 25300, Loss(Val): 0.106525
# Model saved in file: ../save/model-253
# Shuffle data
# Epoch: 254, Step: 25400, Loss(Val): 0.0424672
# Model saved in file: ../save/model-254
# Shuffle data
# Epoch: 255, Step: 25500, Loss(Val): 0.0615594
# Model saved in file: ../save/model-255
# Shuffle data
# Epoch: 256, Step: 25600, Loss(Val): 0.0722503
# Model saved in file: ../save/model-256
# Shuffle data
# Epoch: 257, Step: 25700, Loss(Val): 0.0841331
# Model saved in file: ../save/model-257
# Shuffle data
# Epoch: 258, Step: 25800, Loss(Val): 0.0824187
# Model saved in file: ../save/model-258
# Shuffle data
# Epoch: 259, Step: 25900, Loss(Val): 0.0819885
# Model saved in file: ../save/model-259
# Shuffle data
# Epoch: 260, Step: 26000, Loss(Val): 0.074254
# Model saved in file: ../save/model-260
# Shuffle data
# Epoch: 261, Step: 26100, Loss(Val): 0.098408
# Model saved in file: ../save/model-261
# Shuffle data
# Epoch: 262, Step: 26200, Loss(Val): 0.0824465
# Model saved in file: ../save/model-262
# Shuffle data
# Epoch: 263, Step: 26300, Loss(Val): 0.0611577
# Model saved in file: ../save/model-263
# Shuffle data
# Epoch: 264, Step: 26400, Loss(Val): 0.100945
# Model saved in file: ../save/model-264
# Shuffle data
# Epoch: 265, Step: 26500, Loss(Val): 0.0921153
# Model saved in file: ../save/model-265
# Shuffle data
# Epoch: 266, Step: 26600, Loss(Val): 0.0699509
# Model saved in file: ../save/model-266
# Shuffle data
# Epoch: 267, Step: 26700, Loss(Val): 0.0844116
# Model saved in file: ../save/model-267
# Shuffle data
# Epoch: 268, Step: 26800, Loss(Val): 0.0760855
# Model saved in file: ../save/model-268
# Shuffle data
# Epoch: 269, Step: 26900, Loss(Val): 0.0794913
# Model saved in file: ../save/model-269
# Shuffle data
# Epoch: 270, Step: 27000, Loss(Val): 0.0672912
# Model saved in file: ../save/model-270
# Shuffle data
# Epoch: 271, Step: 27100, Loss(Val): 0.0836946
# Model saved in file: ../save/model-271
# Shuffle data
# Epoch: 272, Step: 27200, Loss(Val): 0.0700778
# Model saved in file: ../save/model-272
# Shuffle data
# Epoch: 273, Step: 27300, Loss(Val): 0.0729647
# Model saved in file: ../save/model-273
# Shuffle data
# Epoch: 274, Step: 27400, Loss(Val): 0.0857181
# Model saved in file: ../save/model-274
# Shuffle data
# Epoch: 275, Step: 27500, Loss(Val): 0.0583222
# Model saved in file: ../save/model-275
# Shuffle data
# Epoch: 276, Step: 27600, Loss(Val): 0.0639345
# Model saved in file: ../save/model-276
# Shuffle data
# Epoch: 277, Step: 27700, Loss(Val): 0.0818411
# Model saved in file: ../save/model-277
# Shuffle data
# Epoch: 278, Step: 27800, Loss(Val): 0.0689843
# Model saved in file: ../save/model-278
# Shuffle data
# Epoch: 279, Step: 27900, Loss(Val): 0.0570039
# Model saved in file: ../save/model-279
# Shuffle data
# Epoch: 280, Step: 28000, Loss(Val): 0.07738
# Model saved in file: ../save/model-280
# Shuffle data
# Epoch: 281, Step: 28100, Loss(Val): 0.0850701
# Model saved in file: ../save/model-281
# Shuffle data
# Epoch: 282, Step: 28200, Loss(Val): 0.0591301
# Model saved in file: ../save/model-282
# Shuffle data
# Epoch: 283, Step: 28300, Loss(Val): 0.0873331
# Model saved in file: ../save/model-283
# Shuffle data
# Epoch: 284, Step: 28400, Loss(Val): 0.106005
# Model saved in file: ../save/model-284
# Shuffle data
# Epoch: 285, Step: 28500, Loss(Val): 0.0502402
# Model saved in file: ../save/model-285
# Shuffle data
# Epoch: 286, Step: 28600, Loss(Val): 0.0780133
# Model saved in file: ../save/model-286
# Shuffle data
# Epoch: 287, Step: 28700, Loss(Val): 0.105879
# Model saved in file: ../save/model-287
# Shuffle data
# Epoch: 288, Step: 28800, Loss(Val): 0.0411963
# Model saved in file: ../save/model-288
# Shuffle data
# Epoch: 289, Step: 28900, Loss(Val): 0.0741729
# Model saved in file: ../save/model-289
# Shuffle data
# Epoch: 290, Step: 29000, Loss(Val): 0.10751
# Model saved in file: ../save/model-290
# Shuffle data
# Epoch: 291, Step: 29100, Loss(Val): 0.0513105
# Model saved in file: ../save/model-291
# Shuffle data
# Epoch: 292, Step: 29200, Loss(Val): 0.0639436
# Model saved in file: ../save/model-292
# Shuffle data
# Epoch: 293, Step: 29300, Loss(Val): 0.076726
# Model saved in file: ../save/model-293
# Shuffle data
# Epoch: 294, Step: 29400, Loss(Val): 0.0884264
# Model saved in file: ../save/model-294
# Shuffle data
# Epoch: 295, Step: 29500, Loss(Val): 0.0766884
# Model saved in file: ../save/model-295
# Shuffle data
# Epoch: 296, Step: 29600, Loss(Val): 0.0796026
# Model saved in file: ../save/model-296
# Shuffle data
# Epoch: 297, Step: 29700, Loss(Val): 0.0732843
# Model saved in file: ../save/model-297
# Shuffle data
# Epoch: 298, Step: 29800, Loss(Val): 0.104337
# Model saved in file: ../save/model-298
# Shuffle data
# Epoch: 299, Step: 29900, Loss(Val): 0.0822276
# Model saved in file: ../save/model-299
# Shuffle data
# Epoch: 300, Step: 30000, Loss(Val): 0.0666448
# Model saved in file: ../save/model-300
# Shuffle data
# Epoch: 301, Step: 30100, Loss(Val): 0.0997343
# Model saved in file: ../save/model-301
# Shuffle data
# Epoch: 302, Step: 30200, Loss(Val): 0.0966388
# Model saved in file: ../save/model-302
# Shuffle data
# Epoch: 303, Step: 30300, Loss(Val): 0.0705798
# Model saved in file: ../save/model-303
# Shuffle data
# Epoch: 304, Step: 30400, Loss(Val): 0.0828023
# Model saved in file: ../save/model-304
# Shuffle data
# Epoch: 305, Step: 30500, Loss(Val): 0.0734148
# Model saved in file: ../save/model-305
# Shuffle data
# Epoch: 306, Step: 30600, Loss(Val): 0.0657429
# Model saved in file: ../save/model-306
# Shuffle data
# Epoch: 307, Step: 30700, Loss(Val): 0.0815563
# Model saved in file: ../save/model-307
# Shuffle data
# Epoch: 308, Step: 30800, Loss(Val): 0.0936171
# Model saved in file: ../save/model-308
# Shuffle data
# Epoch: 309, Step: 30900, Loss(Val): 0.0722947
# Model saved in file: ../save/model-309
# Shuffle data
# Epoch: 310, Step: 31000, Loss(Val): 0.0831932
# Model saved in file: ../save/model-310
# Shuffle data
# Epoch: 311, Step: 31100, Loss(Val): 0.0786985
# Model saved in file: ../save/model-311
# Shuffle data
# Epoch: 312, Step: 31200, Loss(Val): 0.0597451
# Model saved in file: ../save/model-312
# Shuffle data
# Epoch: 313, Step: 31300, Loss(Val): 0.0676097
# Model saved in file: ../save/model-313
# Shuffle data
# Epoch: 314, Step: 31400, Loss(Val): 0.0879668
# Model saved in file: ../save/model-314
# Shuffle data
# Epoch: 315, Step: 31500, Loss(Val): 0.072538
# Model saved in file: ../save/model-315
# Shuffle data
# Epoch: 316, Step: 31600, Loss(Val): 0.0678035
# Model saved in file: ../save/model-316
# Shuffle data
# Epoch: 317, Step: 31700, Loss(Val): 0.0872126
# Model saved in file: ../save/model-317
# Shuffle data
# Epoch: 318, Step: 31800, Loss(Val): 0.0904713
# Model saved in file: ../save/model-318
# Shuffle data
# Epoch: 319, Step: 31900, Loss(Val): 0.0576636
# Model saved in file: ../save/model-319
# Shuffle data
# Epoch: 320, Step: 32000, Loss(Val): 0.0817087
# Model saved in file: ../save/model-320
# Shuffle data
# Epoch: 321, Step: 32100, Loss(Val): 0.106596
# Model saved in file: ../save/model-321
# Shuffle data
# Epoch: 322, Step: 32200, Loss(Val): 0.0553338
# Model saved in file: ../save/model-322
# Shuffle data
# Epoch: 323, Step: 32300, Loss(Val): 0.0826608
# Model saved in file: ../save/model-323
# Shuffle data
# Epoch: 324, Step: 32400, Loss(Val): 0.107392
# Model saved in file: ../save/model-324
# Shuffle data
# Epoch: 325, Step: 32500, Loss(Val): 0.043683
# Model saved in file: ../save/model-325
# Shuffle data
# Epoch: 326, Step: 32600, Loss(Val): 0.0668302
# Model saved in file: ../save/model-326
# Shuffle data
# Epoch: 327, Step: 32700, Loss(Val): 0.111962
# Model saved in file: ../save/model-327
# Shuffle data
# Epoch: 328, Step: 32800, Loss(Val): 0.0559435
# Model saved in file: ../save/model-328
# Shuffle data
# Epoch: 329, Step: 32900, Loss(Val): 0.0601302
# Model saved in file: ../save/model-329
# Shuffle data
# Epoch: 330, Step: 33000, Loss(Val): 0.0869274
# Model saved in file: ../save/model-330
# Shuffle data
# Epoch: 331, Step: 33100, Loss(Val): 0.0920623
# Model saved in file: ../save/model-331
# Shuffle data
# Epoch: 332, Step: 33200, Loss(Val): 0.0772891
# Model saved in file: ../save/model-332
# Shuffle data
# Epoch: 333, Step: 33300, Loss(Val): 0.0775802
# Model saved in file: ../save/model-333
# Shuffle data
# Epoch: 334, Step: 33400, Loss(Val): 0.0728299
# Model saved in file: ../save/model-334
# Shuffle data
# Epoch: 335, Step: 33500, Loss(Val): 0.0994333
# Model saved in file: ../save/model-335
# Shuffle data
# Epoch: 336, Step: 33600, Loss(Val): 0.0886557
# Model saved in file: ../save/model-336
# Shuffle data
# Epoch: 337, Step: 33700, Loss(Val): 0.0680486
# Model saved in file: ../save/model-337
# Shuffle data
# Epoch: 338, Step: 33800, Loss(Val): 0.100711
# Model saved in file: ../save/model-338
# Shuffle data
# Epoch: 339, Step: 33900, Loss(Val): 0.0940437
# Model saved in file: ../save/model-339
# Shuffle data
# Epoch: 340, Step: 34000, Loss(Val): 0.0751351
# Model saved in file: ../save/model-340
# Shuffle data
# Epoch: 341, Step: 34100, Loss(Val): 0.0792065
# Model saved in file: ../save/model-341
# Shuffle data
# Epoch: 342, Step: 34200, Loss(Val): 0.0759153
# Model saved in file: ../save/model-342
# Shuffle data
# Epoch: 343, Step: 34300, Loss(Val): 0.0695238
# Model saved in file: ../save/model-343
# Shuffle data
# Epoch: 344, Step: 34400, Loss(Val): 0.0948246
# Model saved in file: ../save/model-344
# Shuffle data
# Epoch: 345, Step: 34500, Loss(Val): 0.0861116
# Model saved in file: ../save/model-345
# Shuffle data
# Epoch: 346, Step: 34600, Loss(Val): 0.0626784
# Model saved in file: ../save/model-346
# Shuffle data
# Epoch: 347, Step: 34700, Loss(Val): 0.0787957
# Model saved in file: ../save/model-347
# Shuffle data
# Epoch: 348, Step: 34800, Loss(Val): 0.0738058
# Model saved in file: ../save/model-348
# Shuffle data
# Epoch: 349, Step: 34900, Loss(Val): 0.0601364
# Model saved in file: ../save/model-349
# Shuffle data
# Epoch: 350, Step: 35000, Loss(Val): 0.0555552
# Model saved in file: ../save/model-350
# Shuffle data
# Epoch: 351, Step: 35100, Loss(Val): 0.0710863
# Model saved in file: ../save/model-351
# Shuffle data
# Epoch: 352, Step: 35200, Loss(Val): 0.0594744
# Model saved in file: ../save/model-352
# Shuffle data
# Epoch: 353, Step: 35300, Loss(Val): 0.0574146
# Model saved in file: ../save/model-353
# Shuffle data
# Epoch: 354, Step: 35400, Loss(Val): 0.0762502
# Model saved in file: ../save/model-354
# Shuffle data
# Epoch: 355, Step: 35500, Loss(Val): 0.0840513
# Model saved in file: ../save/model-355
# Shuffle data
# Epoch: 356, Step: 35600, Loss(Val): 0.0584193
# Model saved in file: ../save/model-356
# Shuffle data
# Epoch: 357, Step: 35700, Loss(Val): 0.0746682
# Model saved in file: ../save/model-357
# Shuffle data
# Epoch: 358, Step: 35800, Loss(Val): 0.110019
# Model saved in file: ../save/model-358
# Shuffle data
# Epoch: 359, Step: 35900, Loss(Val): 0.0520975
# Model saved in file: ../save/model-359
# Shuffle data
# Epoch: 360, Step: 36000, Loss(Val): 0.0745308
# Model saved in file: ../save/model-360
# Shuffle data
# Epoch: 361, Step: 36100, Loss(Val): 0.105943
# Model saved in file: ../save/model-361
# Shuffle data
# Epoch: 362, Step: 36200, Loss(Val): 0.0491986
# Model saved in file: ../save/model-362
# Shuffle data
# Epoch: 363, Step: 36300, Loss(Val): 0.0635895
# Model saved in file: ../save/model-363
# Shuffle data
# Epoch: 364, Step: 36400, Loss(Val): 0.119979
# Model saved in file: ../save/model-364
# Shuffle data
# Epoch: 365, Step: 36500, Loss(Val): 0.0618943
# Model saved in file: ../save/model-365
# Shuffle data
# Epoch: 366, Step: 36600, Loss(Val): 0.0681009
# Model saved in file: ../save/model-366
# Shuffle data
# Epoch: 367, Step: 36700, Loss(Val): 0.0755742
# Model saved in file: ../save/model-367
# Shuffle data
# Epoch: 368, Step: 36800, Loss(Val): 0.0805203
# Model saved in file: ../save/model-368
# Shuffle data
# Epoch: 369, Step: 36900, Loss(Val): 0.0833842
# Model saved in file: ../save/model-369
# Shuffle data
# Epoch: 370, Step: 37000, Loss(Val): 0.086048
# Model saved in file: ../save/model-370
# Shuffle data
# Epoch: 371, Step: 37100, Loss(Val): 0.0728374
# Model saved in file: ../save/model-371
# Shuffle data
# Epoch: 372, Step: 37200, Loss(Val): 0.0995527
# Model saved in file: ../save/model-372
# Shuffle data
# Epoch: 373, Step: 37300, Loss(Val): 0.0914708
# Model saved in file: ../save/model-373
# Shuffle data
# Epoch: 374, Step: 37400, Loss(Val): 0.0718707
# Model saved in file: ../save/model-374
# Shuffle data
# Epoch: 375, Step: 37500, Loss(Val): 0.0962036
# Model saved in file: ../save/model-375
# Shuffle data
# Epoch: 376, Step: 37600, Loss(Val): 0.0908426
# Model saved in file: ../save/model-376
# Shuffle data
# Epoch: 377, Step: 37700, Loss(Val): 0.0686526
# Model saved in file: ../save/model-377
# Shuffle data
# Epoch: 378, Step: 37800, Loss(Val): 0.0897389
# Model saved in file: ../save/model-378
# Shuffle data
# Epoch: 379, Step: 37900, Loss(Val): 0.0752289
# Model saved in file: ../save/model-379
# Shuffle data
# Epoch: 380, Step: 38000, Loss(Val): 0.0755745
# Model saved in file: ../save/model-380
# Shuffle data
# Epoch: 381, Step: 38100, Loss(Val): 0.0796531
# Model saved in file: ../save/model-381
# Shuffle data
# Epoch: 382, Step: 38200, Loss(Val): 0.0809859
# Model saved in file: ../save/model-382
# Shuffle data
# Epoch: 383, Step: 38300, Loss(Val): 0.0707814
# Model saved in file: ../save/model-383
# Shuffle data
# Epoch: 384, Step: 38400, Loss(Val): 0.0808872
# Model saved in file: ../save/model-384
# Shuffle data
# Epoch: 385, Step: 38500, Loss(Val): 0.0726187
# Model saved in file: ../save/model-385
# Shuffle data
# Epoch: 386, Step: 38600, Loss(Val): 0.0608499
# Model saved in file: ../save/model-386
# Shuffle data
# Epoch: 387, Step: 38700, Loss(Val): 0.0665093
# Model saved in file: ../save/model-387
# Shuffle data
# Epoch: 388, Step: 38800, Loss(Val): 0.0757932
# Model saved in file: ../save/model-388
# Shuffle data
# Epoch: 389, Step: 38900, Loss(Val): 0.0791615
# Model saved in file: ../save/model-389
# Shuffle data
# Epoch: 390, Step: 39000, Loss(Val): 0.0619517
# Model saved in file: ../save/model-390
# Shuffle data
# Epoch: 391, Step: 39100, Loss(Val): 0.076549
# Model saved in file: ../save/model-391
# Shuffle data
# Epoch: 392, Step: 39200, Loss(Val): 0.0881369
# Model saved in file: ../save/model-392
# Shuffle data
# Epoch: 393, Step: 39300, Loss(Val): 0.0572892
# Model saved in file: ../save/model-393
# Shuffle data
# Epoch: 394, Step: 39400, Loss(Val): 0.0702233
# Model saved in file: ../save/model-394
# Shuffle data
# Epoch: 395, Step: 39500, Loss(Val): 0.0936698
# Model saved in file: ../save/model-395
# Shuffle data
# Epoch: 396, Step: 39600, Loss(Val): 0.0462632
# Model saved in file: ../save/model-396
# Shuffle data
# Epoch: 397, Step: 39700, Loss(Val): 0.0828961
# Model saved in file: ../save/model-397
# Shuffle data
# Epoch: 398, Step: 39800, Loss(Val): 0.117513
# Model saved in file: ../save/model-398
# Shuffle data
# Epoch: 399, Step: 39900, Loss(Val): 0.0463193
# Model saved in file: ../save/model-399
# Shuffle data
# Epoch: 400, Step: 40000, Loss(Val): 0.0641914
# Model saved in file: ../save/model-400
# Shuffle data
# Epoch: 401, Step: 40100, Loss(Val): 0.109529
# Model saved in file: ../save/model-401
# Shuffle data
# Epoch: 402, Step: 40200, Loss(Val): 0.0501503
# Model saved in file: ../save/model-402
# Shuffle data
# Epoch: 403, Step: 40300, Loss(Val): 0.0579492
# Model saved in file: ../save/model-403
# Shuffle data
# Epoch: 404, Step: 40400, Loss(Val): 0.0872672
# Model saved in file: ../save/model-404
# Shuffle data
# Epoch: 405, Step: 40500, Loss(Val): 0.087871
# Model saved in file: ../save/model-405
# Shuffle data
# Epoch: 406, Step: 40600, Loss(Val): 0.0739267
# Model saved in file: ../save/model-406
# Shuffle data
# Epoch: 407, Step: 40700, Loss(Val): 0.080723
# Model saved in file: ../save/model-407
# Shuffle data
# Epoch: 408, Step: 40800, Loss(Val): 0.0673719
# Model saved in file: ../save/model-408
# Shuffle data
# Epoch: 409, Step: 40900, Loss(Val): 0.101037
# Model saved in file: ../save/model-409
# Shuffle data
# Epoch: 410, Step: 41000, Loss(Val): 0.0803372
# Model saved in file: ../save/model-410
# Shuffle data
# Epoch: 411, Step: 41100, Loss(Val): 0.0655494
# Model saved in file: ../save/model-411
# Shuffle data
# Epoch: 412, Step: 41200, Loss(Val): 0.0914342
# Model saved in file: ../save/model-412
# Shuffle data
# Epoch: 413, Step: 41300, Loss(Val): 0.10587
# Model saved in file: ../save/model-413
# Shuffle data
# Epoch: 414, Step: 41400, Loss(Val): 0.0689719
# Model saved in file: ../save/model-414
# Shuffle data
# Epoch: 415, Step: 41500, Loss(Val): 0.08706
# Model saved in file: ../save/model-415
# Shuffle data
# Epoch: 416, Step: 41600, Loss(Val): 0.0793116
# Model saved in file: ../save/model-416
# Shuffle data
# Epoch: 417, Step: 41700, Loss(Val): 0.0694239
# Model saved in file: ../save/model-417
# Shuffle data
# Epoch: 418, Step: 41800, Loss(Val): 0.0831051
# Model saved in file: ../save/model-418
# Shuffle data
# Epoch: 419, Step: 41900, Loss(Val): 0.0820836
# Model saved in file: ../save/model-419
# Shuffle data
# Epoch: 420, Step: 42000, Loss(Val): 0.0726169
# Model saved in file: ../save/model-420
# Shuffle data
# Epoch: 421, Step: 42100, Loss(Val): 0.0834899
# Model saved in file: ../save/model-421
# Shuffle data
# Epoch: 422, Step: 42200, Loss(Val): 0.0778979
# Model saved in file: ../save/model-422
# Shuffle data
# Epoch: 423, Step: 42300, Loss(Val): 0.0607078
# Model saved in file: ../save/model-423
# Shuffle data
# Epoch: 424, Step: 42400, Loss(Val): 0.0671949
# Model saved in file: ../save/model-424
# Shuffle data
# Epoch: 425, Step: 42500, Loss(Val): 0.090827
# Model saved in file: ../save/model-425
# Shuffle data
# Epoch: 426, Step: 42600, Loss(Val): 0.0729937
# Model saved in file: ../save/model-426
# Shuffle data
# Epoch: 427, Step: 42700, Loss(Val): 0.0604457
# Model saved in file: ../save/model-427
# Shuffle data
# Epoch: 428, Step: 42800, Loss(Val): 0.0895496
# Model saved in file: ../save/model-428
# Shuffle data
# Epoch: 429, Step: 42900, Loss(Val): 0.089481
# Model saved in file: ../save/model-429
# Shuffle data
# Epoch: 430, Step: 43000, Loss(Val): 0.0547439
# Model saved in file: ../save/model-430
# Shuffle data
# Epoch: 431, Step: 43100, Loss(Val): 0.0837653
# Model saved in file: ../save/model-431
# Shuffle data
# Epoch: 432, Step: 43200, Loss(Val): 0.0984966
# Model saved in file: ../save/model-432
# Shuffle data
# Epoch: 433, Step: 43300, Loss(Val): 0.0437247
# Model saved in file: ../save/model-433
# Shuffle data
# Epoch: 434, Step: 43400, Loss(Val): 0.0808456
# Model saved in file: ../save/model-434
# Shuffle data
# Epoch: 435, Step: 43500, Loss(Val): 0.105822
# Model saved in file: ../save/model-435
# Shuffle data
# Epoch: 436, Step: 43600, Loss(Val): 0.0431894
# Model saved in file: ../save/model-436
# Shuffle data
# Epoch: 437, Step: 43700, Loss(Val): 0.0645509
# Model saved in file: ../save/model-437
# Shuffle data
# Epoch: 438, Step: 43800, Loss(Val): 0.113234
# Model saved in file: ../save/model-438
# Shuffle data
# Epoch: 439, Step: 43900, Loss(Val): 0.0496232
# Model saved in file: ../save/model-439
# Shuffle data
# Epoch: 440, Step: 44000, Loss(Val): 0.0593043
# Model saved in file: ../save/model-440
# Shuffle data
# Epoch: 441, Step: 44100, Loss(Val): 0.0785969
# Model saved in file: ../save/model-441
# Shuffle data
# Epoch: 442, Step: 44200, Loss(Val): 0.082884
# Model saved in file: ../save/model-442
# Shuffle data
# Epoch: 443, Step: 44300, Loss(Val): 0.075302
# Model saved in file: ../save/model-443
# Shuffle data
# Epoch: 444, Step: 44400, Loss(Val): 0.0866611
# Model saved in file: ../save/model-444
# Shuffle data
# Epoch: 445, Step: 44500, Loss(Val): 0.0672881
# Model saved in file: ../save/model-445
# Shuffle data
# Epoch: 446, Step: 44600, Loss(Val): 0.0961445
# Model saved in file: ../save/model-446
# Shuffle data
# Epoch: 447, Step: 44700, Loss(Val): 0.0810984
# Model saved in file: ../save/model-447
# Shuffle data
# Epoch: 448, Step: 44800, Loss(Val): 0.0675489
# Model saved in file: ../save/model-448
# Shuffle data
# Epoch: 449, Step: 44900, Loss(Val): 0.0892904
# Model saved in file: ../save/model-449
# Shuffle data
# Epoch: 450, Step: 45000, Loss(Val): 0.0983686
# Model saved in file: ../save/model-450
# Shuffle data
# Epoch: 451, Step: 45100, Loss(Val): 0.0727329
# Model saved in file: ../save/model-451
# Shuffle data
# Epoch: 452, Step: 45200, Loss(Val): 0.0877606
# Model saved in file: ../save/model-452
# Shuffle data
# Epoch: 453, Step: 45300, Loss(Val): 0.0713734
# Model saved in file: ../save/model-453
# Shuffle data
# Epoch: 454, Step: 45400, Loss(Val): 0.0702787
# Model saved in file: ../save/model-454
# Shuffle data
# Epoch: 455, Step: 45500, Loss(Val): 0.0871675
# Model saved in file: ../save/model-455
# Shuffle data
# Epoch: 456, Step: 45600, Loss(Val): 0.0862137
# Model saved in file: ../save/model-456
# Shuffle data
# Epoch: 457, Step: 45700, Loss(Val): 0.0628314
# Model saved in file: ../save/model-457
# Shuffle data
# Epoch: 458, Step: 45800, Loss(Val): 0.084124
# Model saved in file: ../save/model-458
# Shuffle data
# Epoch: 459, Step: 45900, Loss(Val): 0.0759815
# Model saved in file: ../save/model-459
# Shuffle data
# Epoch: 460, Step: 46000, Loss(Val): 0.0552506
# Model saved in file: ../save/model-460
# Shuffle data
# Epoch: 461, Step: 46100, Loss(Val): 0.0616352
# Model saved in file: ../save/model-461
# Shuffle data
# Epoch: 462, Step: 46200, Loss(Val): 0.0834781
# Model saved in file: ../save/model-462
# Shuffle data
# Epoch: 463, Step: 46300, Loss(Val): 0.0642571
# Model saved in file: ../save/model-463
# Shuffle data
# Epoch: 464, Step: 46400, Loss(Val): 0.0605198
# Model saved in file: ../save/model-464
# Shuffle data
# Epoch: 465, Step: 46500, Loss(Val): 0.0765615
# Model saved in file: ../save/model-465
# Shuffle data
# Epoch: 466, Step: 46600, Loss(Val): 0.0893615
# Model saved in file: ../save/model-466
# Shuffle data
# Epoch: 467, Step: 46700, Loss(Val): 0.0576911
# Model saved in file: ../save/model-467
# Shuffle data
# Epoch: 468, Step: 46800, Loss(Val): 0.0767525
# Model saved in file: ../save/model-468
# Shuffle data
# Epoch: 469, Step: 46900, Loss(Val): 0.0977787
# Model saved in file: ../save/model-469
# Shuffle data
# Epoch: 470, Step: 47000, Loss(Val): 0.0527392
# Model saved in file: ../save/model-470
# Shuffle data
# Epoch: 471, Step: 47100, Loss(Val): 0.078852
# Model saved in file: ../save/model-471
# Shuffle data
# Epoch: 472, Step: 47200, Loss(Val): 0.11225
# Model saved in file: ../save/model-472
# Shuffle data
# Epoch: 473, Step: 47300, Loss(Val): 0.0459809
# Model saved in file: ../save/model-473
# Shuffle data
# Epoch: 474, Step: 47400, Loss(Val): 0.0618279
# Model saved in file: ../save/model-474
# Shuffle data
# Epoch: 475, Step: 47500, Loss(Val): 0.114965
# Model saved in file: ../save/model-475
# Shuffle data
# Epoch: 476, Step: 47600, Loss(Val): 0.0493987
# Model saved in file: ../save/model-476
# Shuffle data
# Epoch: 477, Step: 47700, Loss(Val): 0.0602069
# Model saved in file: ../save/model-477
# Shuffle data
# Epoch: 478, Step: 47800, Loss(Val): 0.0888377
# Model saved in file: ../save/model-478
# Shuffle data
# Epoch: 479, Step: 47900, Loss(Val): 0.0850124
# Model saved in file: ../save/model-479
# Shuffle data
# Epoch: 480, Step: 48000, Loss(Val): 0.0805139
# Model saved in file: ../save/model-480
# Shuffle data
# Epoch: 481, Step: 48100, Loss(Val): 0.0862326
# Model saved in file: ../save/model-481
# Shuffle data
# Epoch: 482, Step: 48200, Loss(Val): 0.0660471
# Model saved in file: ../save/model-482
# Shuffle data
# Epoch: 483, Step: 48300, Loss(Val): 0.0964932
# Model saved in file: ../save/model-483
# Shuffle data
# Epoch: 484, Step: 48400, Loss(Val): 0.0791578
# Model saved in file: ../save/model-484
# Shuffle data
# Epoch: 485, Step: 48500, Loss(Val): 0.0621872
# Model saved in file: ../save/model-485
# Shuffle data
# Epoch: 486, Step: 48600, Loss(Val): 0.101468
# Model saved in file: ../save/model-486
# Shuffle data
# Epoch: 487, Step: 48700, Loss(Val): 0.0985667
# Model saved in file: ../save/model-487
# Shuffle data
# Epoch: 488, Step: 48800, Loss(Val): 0.0708112
# Model saved in file: ../save/model-488
# Shuffle data
# Epoch: 489, Step: 48900, Loss(Val): 0.0925404
# Model saved in file: ../save/model-489
# Shuffle data
# Epoch: 490, Step: 49000, Loss(Val): 0.0808297
# Model saved in file: ../save/model-490
# Shuffle data
# Epoch: 491, Step: 49100, Loss(Val): 0.0754455
# Model saved in file: ../save/model-491
# Shuffle data
# Epoch: 492, Step: 49200, Loss(Val): 0.0910484
# Model saved in file: ../save/model-492
# Shuffle data
# Epoch: 493, Step: 49300, Loss(Val): 0.0845549
# Model saved in file: ../save/model-493
# Shuffle data
# Epoch: 494, Step: 49400, Loss(Val): 0.0658214
# Model saved in file: ../save/model-494
# Shuffle data
# Epoch: 495, Step: 49500, Loss(Val): 0.0865027
# Model saved in file: ../save/model-495
# Shuffle data
# Epoch: 496, Step: 49600, Loss(Val): 0.0780072
# Model saved in file: ../save/model-496
# Shuffle data
# Epoch: 497, Step: 49700, Loss(Val): 0.0569726
# Model saved in file: ../save/model-497
# Shuffle data
# Epoch: 498, Step: 49800, Loss(Val): 0.0624965
# Model saved in file: ../save/model-498
# Shuffle data
# Epoch: 499, Step: 49900, Loss(Val): 0.0756478
# Model saved in file: ../save/model-499
# Shuffle data
# Epoch: 500, Step: 50000, Loss(Val): 0.0644578
# Model saved in file: ../save/model-500
# Shuffle data
# Epoch: 501, Step: 50100, Loss(Val): 0.0570072
# Model saved in file: ../save/model-501
# Shuffle data
# Epoch: 502, Step: 50200, Loss(Val): 0.0857948
# Model saved in file: ../save/model-502
# Shuffle data
# Epoch: 503, Step: 50300, Loss(Val): 0.0863671
# Model saved in file: ../save/model-503
# Shuffle data
# Epoch: 504, Step: 50400, Loss(Val): 0.0611057
# Model saved in file: ../save/model-504
# Shuffle data
# Epoch: 505, Step: 50500, Loss(Val): 0.0837247
# Model saved in file: ../save/model-505
# Shuffle data
# Epoch: 506, Step: 50600, Loss(Val): 0.104343
# Model saved in file: ../save/model-506
# Shuffle data
# Epoch: 507, Step: 50700, Loss(Val): 0.0455531
# Model saved in file: ../save/model-507
# Shuffle data
# Epoch: 508, Step: 50800, Loss(Val): 0.0762602
# Model saved in file: ../save/model-508
# Shuffle data
# Epoch: 509, Step: 50900, Loss(Val): 0.10814
# Model saved in file: ../save/model-509
# Shuffle data
# Epoch: 510, Step: 51000, Loss(Val): 0.0435956
# Model saved in file: ../save/model-510
# Shuffle data
# Epoch: 511, Step: 51100, Loss(Val): 0.0707354
# Model saved in file: ../save/model-511
# Shuffle data
# Epoch: 512, Step: 51200, Loss(Val): 0.120218
# Model saved in file: ../save/model-512
# Shuffle data
# Epoch: 513, Step: 51300, Loss(Val): 0.0552561
# Model saved in file: ../save/model-513
# Shuffle data
# Epoch: 514, Step: 51400, Loss(Val): 0.0568781
# Model saved in file: ../save/model-514
# Shuffle data
# Epoch: 515, Step: 51500, Loss(Val): 0.0829468
# Model saved in file: ../save/model-515
# Shuffle data
# Epoch: 516, Step: 51600, Loss(Val): 0.077016
# Model saved in file: ../save/model-516
# Shuffle data
# Epoch: 517, Step: 51700, Loss(Val): 0.0754195
# Model saved in file: ../save/model-517
# Shuffle data
# Epoch: 518, Step: 51800, Loss(Val): 0.0902067
# Model saved in file: ../save/model-518
# Shuffle data
# Epoch: 519, Step: 51900, Loss(Val): 0.0674222
# Model saved in file: ../save/model-519
# Shuffle data
# Epoch: 520, Step: 52000, Loss(Val): 0.0930047
# Model saved in file: ../save/model-520
# Shuffle data
# Epoch: 521, Step: 52100, Loss(Val): 0.0791641
# Model saved in file: ../save/model-521
# Shuffle data
# Epoch: 522, Step: 52200, Loss(Val): 0.0612627
# Model saved in file: ../save/model-522
# Shuffle data
# Epoch: 523, Step: 52300, Loss(Val): 0.0898204
# Model saved in file: ../save/model-523
# Shuffle data
# Epoch: 524, Step: 52400, Loss(Val): 0.0890751
# Model saved in file: ../save/model-524
# Shuffle data
# Epoch: 525, Step: 52500, Loss(Val): 0.0727072
# Model saved in file: ../save/model-525
# Shuffle data
# Epoch: 526, Step: 52600, Loss(Val): 0.0843766
# Model saved in file: ../save/model-526
# Shuffle data
# Epoch: 527, Step: 52700, Loss(Val): 0.0757708
# Model saved in file: ../save/model-527
# Shuffle data
# Epoch: 528, Step: 52800, Loss(Val): 0.0724165
# Model saved in file: ../save/model-528
# Shuffle data
# Epoch: 529, Step: 52900, Loss(Val): 0.0850867
# Model saved in file: ../save/model-529
# Shuffle data
# Epoch: 530, Step: 53000, Loss(Val): 0.080229
# Model saved in file: ../save/model-530
# Shuffle data
# Epoch: 531, Step: 53100, Loss(Val): 0.0628183
# Model saved in file: ../save/model-531
# Shuffle data
# Epoch: 532, Step: 53200, Loss(Val): 0.0835667
# Model saved in file: ../save/model-532
# Shuffle data
# Epoch: 533, Step: 53300, Loss(Val): 0.0801844
# Model saved in file: ../save/model-533
# Shuffle data
# Epoch: 534, Step: 53400, Loss(Val): 0.0734955
# Model saved in file: ../save/model-534
# Shuffle data
# Epoch: 535, Step: 53500, Loss(Val): 0.0695435
# Model saved in file: ../save/model-535
# Shuffle data
# Epoch: 536, Step: 53600, Loss(Val): 0.082915
# Model saved in file: ../save/model-536
# Shuffle data
# Epoch: 537, Step: 53700, Loss(Val): 0.0665401
# Model saved in file: ../save/model-537
# Shuffle data
# Epoch: 538, Step: 53800, Loss(Val): 0.0523912
# Model saved in file: ../save/model-538
# Shuffle data
# Epoch: 539, Step: 53900, Loss(Val): 0.074419
# Model saved in file: ../save/model-539
# Shuffle data
# Epoch: 540, Step: 54000, Loss(Val): 0.0884548
# Model saved in file: ../save/model-540
# Shuffle data
# Epoch: 541, Step: 54100, Loss(Val): 0.0552016
# Model saved in file: ../save/model-541
# Shuffle data
# Epoch: 542, Step: 54200, Loss(Val): 0.0777172
# Model saved in file: ../save/model-542
# Shuffle data
# Epoch: 543, Step: 54300, Loss(Val): 0.0971134
# Model saved in file: ../save/model-543
# Shuffle data
# Epoch: 544, Step: 54400, Loss(Val): 0.0501033
# Model saved in file: ../save/model-544
# Shuffle data
# Epoch: 545, Step: 54500, Loss(Val): 0.0778427
# Model saved in file: ../save/model-545
# Shuffle data
# Epoch: 546, Step: 54600, Loss(Val): 0.117863
# Model saved in file: ../save/model-546
# Shuffle data
# Epoch: 547, Step: 54700, Loss(Val): 0.0448935
# Model saved in file: ../save/model-547
# Shuffle data
# Epoch: 548, Step: 54800, Loss(Val): 0.0716884
# Model saved in file: ../save/model-548
# Shuffle data
# Epoch: 549, Step: 54900, Loss(Val): 0.113992
# Model saved in file: ../save/model-549
# Shuffle data
# Epoch: 550, Step: 55000, Loss(Val): 0.0513203
# Model saved in file: ../save/model-550
# Shuffle data
# Epoch: 551, Step: 55100, Loss(Val): 0.0547234
# Model saved in file: ../save/model-551
# Shuffle data
# Epoch: 552, Step: 55200, Loss(Val): 0.0858243
# Model saved in file: ../save/model-552
# Shuffle data
# Epoch: 553, Step: 55300, Loss(Val): 0.0782929
# Model saved in file: ../save/model-553
# Shuffle data
# Epoch: 554, Step: 55400, Loss(Val): 0.0696015
# Model saved in file: ../save/model-554
# Shuffle data
# Epoch: 555, Step: 55500, Loss(Val): 0.0897361
# Model saved in file: ../save/model-555
# Shuffle data
# Epoch: 556, Step: 55600, Loss(Val): 0.06213
# Model saved in file: ../save/model-556
# Shuffle data
# Epoch: 557, Step: 55700, Loss(Val): 0.0990735
# Model saved in file: ../save/model-557
# Shuffle data
# Epoch: 558, Step: 55800, Loss(Val): 0.0814279
# Model saved in file: ../save/model-558
# Shuffle data
# Epoch: 559, Step: 55900, Loss(Val): 0.064831
# Model saved in file: ../save/model-559
# Shuffle data
# Epoch: 560, Step: 56000, Loss(Val): 0.104928
# Model saved in file: ../save/model-560
# Shuffle data
# Epoch: 561, Step: 56100, Loss(Val): 0.0937778
# Model saved in file: ../save/model-561
# Shuffle data
# Epoch: 562, Step: 56200, Loss(Val): 0.0598093
# Model saved in file: ../save/model-562
# Shuffle data
# Epoch: 563, Step: 56300, Loss(Val): 0.0872657
# Model saved in file: ../save/model-563
# Shuffle data
# Epoch: 564, Step: 56400, Loss(Val): 0.0762597
# Model saved in file: ../save/model-564
# Shuffle data
# Epoch: 565, Step: 56500, Loss(Val): 0.0775591
# Model saved in file: ../save/model-565
# Shuffle data
# Epoch: 566, Step: 56600, Loss(Val): 0.0805997
# Model saved in file: ../save/model-566
# Shuffle data
# Epoch: 567, Step: 56700, Loss(Val): 0.0849541
# Model saved in file: ../save/model-567
# Shuffle data
# Epoch: 568, Step: 56800, Loss(Val): 0.0572163
# Model saved in file: ../save/model-568
# Shuffle data
# Epoch: 569, Step: 56900, Loss(Val): 0.0837284
# Model saved in file: ../save/model-569
# Shuffle data
# Epoch: 570, Step: 57000, Loss(Val): 0.0782475
# Model saved in file: ../save/model-570
# Shuffle data
# Epoch: 571, Step: 57100, Loss(Val): 0.0599021
# Model saved in file: ../save/model-571
# Shuffle data
# Epoch: 572, Step: 57200, Loss(Val): 0.0643774
# Model saved in file: ../save/model-572
# Shuffle data
# Epoch: 573, Step: 57300, Loss(Val): 0.0771292
# Model saved in file: ../save/model-573
# Shuffle data
# Epoch: 574, Step: 57400, Loss(Val): 0.0634349
# Model saved in file: ../save/model-574
# Shuffle data
# Epoch: 575, Step: 57500, Loss(Val): 0.0614354
# Model saved in file: ../save/model-575
# Shuffle data
# Epoch: 576, Step: 57600, Loss(Val): 0.0859426
# Model saved in file: ../save/model-576
# Shuffle data
# Epoch: 577, Step: 57700, Loss(Val): 0.0868255
# Model saved in file: ../save/model-577
# Shuffle data
# Epoch: 578, Step: 57800, Loss(Val): 0.057373
# Model saved in file: ../save/model-578
# Shuffle data
# Epoch: 579, Step: 57900, Loss(Val): 0.0824198
# Model saved in file: ../save/model-579
# Shuffle data
# Epoch: 580, Step: 58000, Loss(Val): 0.0964265
# Model saved in file: ../save/model-580
# Shuffle data
# Epoch: 581, Step: 58100, Loss(Val): 0.0505717
# Model saved in file: ../save/model-581
# Shuffle data
# Epoch: 582, Step: 58200, Loss(Val): 0.0808668
# Model saved in file: ../save/model-582
# Shuffle data
# Epoch: 583, Step: 58300, Loss(Val): 0.112609
# Model saved in file: ../save/model-583
# Shuffle data
# Epoch: 584, Step: 58400, Loss(Val): 0.0438628
# Model saved in file: ../save/model-584
# Shuffle data
# Epoch: 585, Step: 58500, Loss(Val): 0.0639729
# Model saved in file: ../save/model-585
# Shuffle data
# Epoch: 586, Step: 58600, Loss(Val): 0.1117
# Model saved in file: ../save/model-586
# Shuffle data
# Epoch: 587, Step: 58700, Loss(Val): 0.0484896
# Model saved in file: ../save/model-587
# Shuffle data
# Epoch: 588, Step: 58800, Loss(Val): 0.0647948
# Model saved in file: ../save/model-588
# Shuffle data
# Epoch: 589, Step: 58900, Loss(Val): 0.0829949
# Model saved in file: ../save/model-589
# Shuffle data
# Epoch: 590, Step: 59000, Loss(Val): 0.079003
# Model saved in file: ../save/model-590
# Shuffle data
# Epoch: 591, Step: 59100, Loss(Val): 0.0776844
# Model saved in file: ../save/model-591
# Shuffle data
# Epoch: 592, Step: 59200, Loss(Val): 0.0809783
# Model saved in file: ../save/model-592
# Shuffle data
# Epoch: 593, Step: 59300, Loss(Val): 0.0543918
# Model saved in file: ../save/model-593
# Shuffle data
# Epoch: 594, Step: 59400, Loss(Val): 0.0968727
# Model saved in file: ../save/model-594
# Shuffle data
# Epoch: 595, Step: 59500, Loss(Val): 0.0821017
# Model saved in file: ../save/model-595
# Shuffle data
# Epoch: 596, Step: 59600, Loss(Val): 0.0593276
# Model saved in file: ../save/model-596
# Shuffle data
# Epoch: 597, Step: 59700, Loss(Val): 0.0914996
# Model saved in file: ../save/model-597
# Shuffle data
# Epoch: 598, Step: 59800, Loss(Val): 0.0902484
# Model saved in file: ../save/model-598
# Shuffle data
# Epoch: 599, Step: 59900, Loss(Val): 0.0697202
# Model saved in file: ../save/model-599
# Shuffle data
